# %%
# 下载数据
import yfinance as yf
ticker = '600519.SS'
data = yf.download(ticker, start='2023-12-01', end='2023-12-31', interval='1d',threads = False,proxy="http://127.0.0.1:7890")
# Out:
# /var/folders/qb/_zmdxt6n29n5h6hxbt7v0v0c0000gn/T/ipykernel_29303/914695685.py:4: DeprecationWarning: Set proxy via new config function: yf.set_config(proxy=proxy)
#   data = yf.download(ticker, start='2023-12-01', end='2023-12-31', interval='1d',threads = False,proxy="http://127.0.0.1:7890")
# /var/folders/qb/_zmdxt6n29n5h6hxbt7v0v0c0000gn/T/ipykernel_29303/914695685.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start='2023-12-01', end='2023-12-31', interval='1d',threads = False,proxy="http://127.0.0.1:7890")
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf
import time

ticker = '600519.SS'
data = yf.download(ticker, start='2023-06-01', end='2023-12-31', interval='1d', threads=False)
if not data.empty:
    print(data.head())
else:
    print("No data returned.")
time.sleep(2)  # 2-second delay if fetching more tickers
# Out:
# /var/folders/qb/_zmdxt6n29n5h6hxbt7v0v0c0000gn/T/ipykernel_29303/3790971729.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start='2023-06-01', end='2023-12-31', interval='1d', threads=False)
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open    Volume
# Ticker        600519.SS    600519.SS    600519.SS    600519.SS 600519.SS
# Date
# 2023-06-01  1506.844482  1542.831775  1490.338346  1490.338346   2864525
# 2023-06-02  1538.788086  1541.136934  1507.019388  1515.207972   2505802
# 2023-06-05  1533.630005  1550.099261  1531.787807  1534.698511   1620050
# 2023-06-06  1535.463013  1551.130918  1521.241296  1538.235530   1991392
# 2023-06-07  1520.642578  1546.341266  1519.813566  1540.989626   1788964
